# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\sahad\anaconda3\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\sahad\anaconda3\lib\site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\sahad\anaconda3\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\sahad\anaconda3\lib\site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\sahad\anaconda3\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\sahad\anaconda3\lib\site-packages (from mlxtend) (3.9.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\sahad\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sahad\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sahad\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sahad\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\sahad\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
df=pd.read_csv('C:/Users/sahad/Documents/Machine_Learning_Campus_x/placement.csv')
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %% [markdown]
# df.iloc[:,1:]

# %% [markdown]
# #Pre processing
# Removing the first Column

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.iloc[:,-1:]
# Out:
#     placement
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0
# ..        ...
# 95          0
# 96          0
# 97          1
# 98          1
# 99          1
#
# [100 rows x 1 columns]

# %%
df.iloc[:,0:2]
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
#Exploratory Data Analysis
# Out:
#   Cell In[14], line 1
#     Exploratory Data Analysis
#                 ^
# SyntaxError: invalid syntax

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
print(x)
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
#Import sklearn model 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 x_train.shape
#
# NameError: name 'x_train' is not defined

# %%
x_test.shape
# Out:
# (10, 2)

# %%
y_train.shape
# Out:
# (90,)

# %%
y_test.shape
# Out:
# (10,)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test  = scaler.transform(x_test)

# %% [markdown]
# scaler = StandardScaler()
# scaler.fit(x_train)

# %%
x_train
# Out:
# array([[ 1.79991262, -1.11114192],
#        [-0.96770529,  0.99312484],
#        [-0.88121723,  0.69251531],
#        [ 0.07015143,  0.64241372],
#        [-0.44877693, -0.2343641 ],
#        [-0.10282469,  1.06827723],
#        [-0.44877693,  0.39190577],
#        [-0.44877693,  0.29170259],
#        [-0.88121723, -1.56205623],
#        [-0.70824111,  0.11634702],
#        [-0.62175305,  2.52122333],
#        [ 0.07015143,  0.01614385],
#        [ 0.50259172,  0.91797246],
#        [-0.44877693, -0.40971967],
#        [ 0.50259172, -0.83558318],
#        [ 0.84854396,  0.36685497],
#        [ 1.45396038,  0.11634702],
#        [ 2.23235291, -0.08405933],
#        [ 1.02152008, -1.88771656],
#        [ 0.3296156 ,  0.09129623],
#        [-1.65960976, -1.2113451 ],
#        [-0.62175305,  0.94302325],
#        [ 0.93503202, -0.28446569],
#        [ 0.93503202, -1.48690384],
#        [-0.79472917, -0.81053238],
#        [ 0.84854396, -0.68527841],
#        [-1.05419335, -0.91073556],
#        [ 0.15663949,  0.2165502 ],
#        [ 1.36747232,  0.86787087],
#        [-0.88121723, -0.08405933],
#        [-0.79472917, -1.51195464],
#        [ 1.02152008,  0.69251531],
#        [ 1.36747232,  0.16644861],
#        [ 1.88640068,  1.06827723],
#        [-2.09205006,  2.74668048],
#        [-0.70824111,  1.31878518],
#        [-1.31365753, -2.03802133],
#        [ 0.15663949, -1.46185305],
#        [-0.18931275,  0.49210895],
#        [ 0.15663949,  0.81776928],
#        [-0.62175305, -0.83558318],
#        [-0.01633663, -0.43477046],
#        [ 0.24312755, -0.2594149 ],
#        [ 1.6269365 , -0.2343641 ],
#        [-1.05419335, -0.05900854],
#        [-0.96770529,  0.44200736],
#        [-0.70824111, -1.43680225],
#        [ 0.07015143, -1.96286895],
#        [ 0.7620559 , -0.00890695],
#        [ 1.45396038, -0.86063397],
#        [-1.31365753,  0.64241372],
#        [ 1.1944962 , -0.93578636],
#        [ 0.07015143, -0.53497364],
#        [ 0.41610366,  0.44200736],
#        [-0.96770529,  1.14342961],
#        [-0.53526499, -0.2343641 ],
#        [ 1.28098426,  0.2165502 ],
#        [ 0.07015143, -1.43680225],
#        [ 1.88640068,  0.64241372],
#        [-1.40014559,  1.92000425],
#        [-0.88121723,  0.26665179],
#        [ 0.67556784,  0.76766769],
#        [-0.18931275,  1.14342961],
#        [ 1.36747232, -1.56205623],
#        [ 0.93503202,  0.39190577],
#        [-1.65960976, -0.58507523],
#        [-0.18931275,  0.2165502 ],
#        [ 0.67556784,  1.46908995],
#        [-2.26502618,  1.49414074],
#        [ 0.3296156 ,  0.11634702],
#        [-0.96770529, -0.28446569],
#        [ 0.15663949, -1.06104033],
#        [ 0.3296156 , -0.50992285],
#        [ 0.58907978,  0.36685497],
#        [-1.14068141,  0.56726133],
#        [ 2.05937679,  1.11837882],
#        [-0.10282469,  0.46705815],
#        [ 1.1944962 , -0.18426251],
#        [-0.18931275,  0.41695656],
#        [-0.62175305, -0.33456728],
#        [ 0.41610366, -0.18426251],
#        [-0.53526499, -0.05900854],
#        [-0.62175305,  0.2165502 ],
#        [ 0.58907978, -0.08405933],
#        [ 0.93503202,  1.29373438],
#        [ 0.50259172, -2.1632753 ],
#        [-1.05419335, -1.78751338],
#        [-0.88121723,  1.81980107],
#        [-0.79472917, -0.13416092],
#        [-1.74609782, -0.35961808]])

# %%
x_test
# Out:
# array([[ 0.84854396,  0.39190577],
#        [ 0.15663949, -0.50992285],
#        [ 0.7620559 , -0.83558318],
#        [ 1.1944962 ,  0.34180418],
#        [ 0.7620559 , -0.28446569],
#        [ 0.50259172,  0.16644861],
#        [ 0.7620559 ,  0.44200736],
#        [ 1.1944962 , -1.83761497],
#        [ 0.93503202,  1.89495346],
#        [-0.88121723,  0.79271848]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
#model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 60    1
# 14    0
# 35    1
# 61    1
# 93    1
# 57    1
# 43    1
# 77    1
# 26    1
# 76    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\sahad\anaconda3\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\sahad\anaconda3\lib\site-packages (from mlxtend) (1.13.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\sahad\anaconda3\lib\site-packages (from mlxtend) (1.26.4)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\sahad\anaconda3\lib\site-packages (from mlxtend) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\sahad\anaconda3\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\sahad\anaconda3\lib\site-packages (from mlxtend) (3.9.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\sahad\anaconda3\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sahad\anaconda3\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sahad\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sahad\anaconda3\lib\site-packages (from pandas>=0.24.2->mlxtend) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\sahad\anaconda3\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\sahad\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
plot_decision_regions(x_train, y_train.values, clf= clf, legend=2)
# Out:
# <Axes: >

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(x=x_train, y=y_train.values, clf=clf,legends=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 from mlxtend.plotting import plot_decision_regions
# ----> 2 plot_decision_regions(x=x_train, y=y_train.values, clf=clf,legends=2)
#
# TypeError: plot_decision_regions() got an unexpected keyword argument 'x'

# %%
import pickle

# %%
import pickle
pickle.dump(clf, open('model.pkl', 'wb'))
